# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilham-0104/Machine_Learning_Data_Science/blob/main/bag_9_OCR_Pandas_ilham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr

# %%
from easyocr import Reader
import cv2

# %%
img = cv2.imread("/content/WhatsApp Image 2024-07-20 at 14.42.08_1e6cb992.jpg")
img.shape
# Out:
# (800, 1200, 3)

# %%
reader = Reader(["en"]) # english
results = reader.readtext(img) # syntax untuk membaca text pada gambar
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
results
# Out:
# [([[328, 374], [380, 374], [380, 468], [328, 468]], 'p', 0.12180749514321665),
#  ([[461, 341], [579, 341], [579, 451], [461, 451]], '591', 0.9978668517330571),
#  ([[633, 333], [695, 333], [695, 413], [633, 413]], 'RI', 0.7776167947685878),
#  ([[480, 432], [576, 432], [576, 484], [480, 484]],
#   '01 20',
#   0.37481888757602877)]

# %%
for (bbox, text, prob) in results:
	# display the OCR'd text and associated probability
	print("[INFO] {:.4f}: {}".format(prob, text))
	# unpack the bounding box
	(tl, tr, br, bl) = bbox
	tl = (int(tl[0]), int(tl[1]))
	tr = (int(tr[0]), int(tr[1]))
	br = (int(br[0]), int(br[1]))
	bl = (int(bl[0]), int(bl[1]))
	# cleanup the text and draw the box surrounding the text along
	# with the OCR'd text itself
	cv2.rectangle(img, tl, br, (0, 255, 0), 2)
	cv2.putText(img, text, (tl[0], tl[1] - 10),
		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# show the output imag
# Out:
# [INFO] 0.1218: p
# [INFO] 0.9979: 591
# [INFO] 0.7776: RI
# [INFO] 0.3748: 01 20

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800>

# %%
img = cv2.imread("/content/WhatsApp Image 2024-07-20 at 14.42.39_c44eefa2.jpg")
img.shape
# Out:
# (800, 1200, 3)

# %%
reader = Reader(["en"]) # english
results = reader.readtext(img) # syntax untuk membaca text pada gambar
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
results
# Out:
# [([[654, 98], [700, 98], [700, 128], [654, 128]], 'cCal', 0.5561966896057129),
#  ([[261, 549], [309, 549], [309, 565], [261, 565]],
#   'KRR580',
#   0.08010567651982166),
#  ([[1077, 545], [1125, 545], [1125, 561], [1077, 561]],
#   'C2rSC0"',
#   0.030071908460664692),
#  ([[258, 564], [310, 564], [310, 590], [258, 590]],
#   '37-L',
#   0.6220410466194153),
#  ([[1078, 556], [1130, 556], [1130, 584], [1078, 584]],
#   '36.22',
#   0.5201821842171306),
#  ([[971.4929798734366, 235.13806578484224],
#    [1003.9782341251024, 240.79249579164494],
#    [1001.5070201265634, 253.86193421515776],
#    [969.0217658748976, 248.20750420835506]],
#   'Acrasto',
#   0.1976392705774215)]

# %%
for (bbox, text, prob) in results:
	# display the OCR'd text and associated probability
	print("[INFO] {:.4f}: {}".format(prob, text))
	# unpack the bounding box
	(tl, tr, br, bl) = bbox
	tl = (int(tl[0]), int(tl[1]))
	tr = (int(tr[0]), int(tr[1]))
	br = (int(br[0]), int(br[1]))
	bl = (int(bl[0]), int(bl[1]))
	# cleanup the text and draw the box surrounding the text along
	# with the OCR'd text itself
	cv2.rectangle(img, tl, br, (0, 255, 0), 2)
	cv2.putText(img, text, (tl[0], tl[1] - 10),
		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# show the output imag
# Out:
# [INFO] 0.5562: cCal
# [INFO] 0.0801: KRR580
# [INFO] 0.0301: C2rSC0"
# [INFO] 0.6220: 37-L
# [INFO] 0.5202: 36.22
# [INFO] 0.1976: Acrasto

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800>

# %%
img = cv2.imread("/content/WhatsApp Image 2024-07-20 at 14.42.56_6db6e0d5.jpg")
img.shape
# Out:
# (338, 600, 3)

# %%
reader = Reader(["en"]) # english
results = reader.readtext(img) # syntax untuk membaca text pada gambar
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
for (bbox, text, prob) in results:
	# display the OCR'd text and associated probability
	print("[INFO] {:.4f}: {}".format(prob, text))
	# unpack the bounding box
	(tl, tr, br, bl) = bbox
	tl = (int(tl[0]), int(tl[1]))
	tr = (int(tr[0]), int(tr[1]))
	br = (int(br[0]), int(br[1]))
	bl = (int(bl[0]), int(bl[1]))
	# cleanup the text and draw the box surrounding the text along
	# with the OCR'd text itself
	cv2.rectangle(img, tl, br, (0, 255, 0), 2)
	cv2.putText(img, text, (tl[0], tl[1] - 10),
		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# show the output imag
# Out:
# [INFO] 0.0124: To
# [INFO] 0.1621: 2839  EB
# [INFO] 0.9150: WIJAYA PLAT
# [INFO] 0.9440: 1118 ILA
# [INFO] 1.0000: 88
# [INFO] 0.4960: LNT
# [INFO] 0.9241: PUIRA
# [INFO] 0.3602: 5879  ZTR|
# [INFO] 0.4106: PAHJALU
# [INFO] 0.2759: Udj
# [INFO] 1.0000: 88
# [INFO] 0.9500: LNI
# [INFO] 0.2502: 0022 40234277]
# [INFO] 0.6312: 5879  ZTR
# [INFO] 0.7391: UdJ
# [INFO] 0.5909: 1539  Ri
# [INFO] 0.7142: 1599 SAB
# [INFO] 0.6205: 9515
# [INFO] 0.3256: 2407 VCP
# [INFO] 0.0326: JLJ
# [INFO] 0.6352: 1599  SAB
# [INFO] 0.9638: 2407 VCP
# [INFO] 0.3972: 2936 ABAI
# [INFO] 0.8227: 2104
# [INFO] 0.3811: 1578   YBH'
# [INFO] 0.2713: D 2104
# [INFO] 0.1817: 1419 MGh
# [INFO] 0.2456: Ohve-deti
# [INFO] 0.1457: Jufe
# [INFO] 0.2617: '5372
# [INFO] 0.1877: 5372t

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x338>
